# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('cluster2.csv')
print("Dimensions of the data = {}".format(df.shape))
# Out:
# Dimensions of the data = (1300, 2)

# %%
df[:5]
# Out:
#           X         Y
# 0  1.070487  1.328147
# 1  1.072777  1.191249
# 2  0.328029  1.261713
# 3  0.600926  1.254465
# 4  0.759281  1.284541

# %%
X = df.values
X[:5]
# Out:
# array([[1.07048688, 1.3281469 ],
#        [1.07277723, 1.19124898],
#        [0.3280287 , 1.26171275],
#        [0.60092578, 1.2544653 ],
#        [0.75928098, 1.28454059]])

# %%
plt.figure(figsize=(5,5))
plt.scatter(X[:, 0], X[:, 1], s=4)
plt.show()

# %%
K_means = KMeans(n_clusters=4, random_state=0)
y_pred = K_means.fit_predict(X)
print(y_pred[:10])
# Out:
# [3 3 0 0 3 0 0 3 0 3]

# %%
print(K_means.cluster_centers_)
# Out:
# [[0.34246812 1.24954935]
#  [1.03649222 0.44492065]
#  [0.38107742 0.43718073]
#  [1.01140173 1.16353809]]

# %%
plt.figure(figsize=(5,5))
plt.scatter(X[:, 0], X[:, 1], c=y_pred, s=4, cmap="tab10")
plt.show()
